# %% [markdown]
# The goal of this exercise is to suggest to Instacart customers items that they might want to purchase based on past orders. The point is not to create an award-winning algorithm, but to place yourself in the shoes of a data science consultant.
#
# 1. Data Exploration
#     1. What initial insights can you get from a first exploration of the dataset?
#     2. Do some variables seem to have more importance than other? What transformations might be needed?
# 2. Prediction
#     1. Describe your overall approach: how did you formulate the problem to make recommendations?
#     2. What model did you choose? Why?
#     3. How did you assess performance of your model? Which metrics seemed particularly important to you?
#     4. Please present your results and model performance
#     5. How would you suggest delivering the recommendations to your client?
# 3. Insights and Next Steps
#     1. What insights can you extract from your analysis?
#     2. What are some of the things you would suggest as next steps for your client?

# %% [markdown]
# # Recommendation Model

# %% [markdown]
# I read few materials based on building recommendation models.
#
# Couple of the main priorities that I assigned for the recommendation model were -
# 1. Using technologies such as Spark makes stream processing faster.
# 2. Generate recommendation with speed and in a distributed framework.
# 3. Use minimal code for the recommendation model.
#
# After surfing through collaborative filtering section from MLlib, eventually this post from databricks caught my attention. They implemented the FP-Growth algorithm for building recommendations and explains how algorithms and infrastructure is necessary to generate your association rules on a distributed platform with the ever growing ecommerce data.
#
# https://databricks.com/blog/2018/09/18/simplify-market-basket-analysis-using-fp-growth-on-databricks.html
#
# http://www.borgelt.net/doc/fpgrowth/fpgrowth.html

# %% [markdown]
# # Loading libraries

# %%
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import collect_set, col, count, collect_list
from pyspark.ml.fpm import FPGrowth
spark = SparkSession.builder.appName('MarketBasketAnalysis').getOrCreate()
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator

# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
#Loading all the data-sets using spark
aisles = spark.read.csv("aisles.csv", header=True, inferSchema=True)
departments = spark.read.csv("departments.csv", header=True, inferSchema=True)
order_products_prior = spark.read.csv("order_products__prior.csv", header=True, inferSchema=True)
order_products_train = spark.read.csv("order_products__train_cap.csv", header=True, inferSchema=True)
order_products_test = spark.read.csv("order_products__test_cap.csv", header=True, inferSchema=True)
orders = spark.read.csv("orders.csv", header=True, inferSchema=True)
products = spark.read.csv("products.csv", header=True, inferSchema=True)

# creating temporary tables
aisles.createOrReplaceTempView("aisles")
departments.createOrReplaceTempView("departments")
order_products_prior.createOrReplaceTempView("order_products_prior")
order_products_train.createOrReplaceTempView("order_products_train")
order_products_test.createOrReplaceTempView("order_products_test")
orders.createOrReplaceTempView("orders")
products.createOrReplaceTempView("products")

# %% [markdown]
# # Association Mining

# %% [markdown]
# Association rule learning is a rule-based machine learning method for discovering interesting relations between variables in large databases. It is intended to identify strong rules discovered in databases using some measures of interestingness. To prepare our data for spark processing, we will organize the data by shopping basket. Which means that, each row of our DataFrame represents an order_id with each items column containing an array of items ordered within that order.

# %%
# organize by shopping basket
data = spark.sql("select p.product_name, o.order_id from products p inner join order_products_train o where o.product_id = p.product_id")
shopping_baskets = data.groupBy('order_id').agg(collect_set('product_name').alias('basket')).orderBy("order_id", ascending=True)
shopping_baskets.createOrReplaceTempView('shopping_baskets')
shopping_baskets.show()
# Out:
# +--------+--------------------+
# |order_id|              basket|
# +--------+--------------------+
# |      36|[Cage Free Extra ...|
# |      38|[Bunched Cilantro...|
# |     170|[Classic Movie Th...|
# |     226|["Magic Tape Refi...|
# |     349|[Organic Beef Hot...|
# |     456|[Petite Peas, Lar...|
# |     719|[Heavy Duty Scrub...|
# |     762|[Organic Cucumber...|
# |     844|[Organic Red Radi...|
# |     878|[Organic Cilantro...|
# |     915|[Heavy Duty Paper...|
# |     988|[Whipped Light Cr...|
# |    1001|[Organic Roma Tom...|
# |    1032|[Organic Living B...|
# |    1042|[Pure Irish Butte...|
# |    1077|[Sparkling Water,...|
# |    1086|[Organic Mint, Li...|
# |    1119|[Shallot, Large L...|
# |    1120|[Kettle Cooked Po...|
# |    1139|[Cinnamon Rolls w...|
# +--------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # FP-Growth
#
# FP-growth is a program for frequent item set mining, a data mining method that was originally developed for market basket analysis. Frequent item set mining aims at finding regularities in the shopping behavior of the customers of supermarkets, mail-order companies and online shops. FP-Growth is an improvement of apriori designed to eliminate some of the heavy bottlenecks in apriori.
#
# In particular, it tries to identify sets of products that are frequently bought together. Once identified, such sets of associated products may be used to optimize the organization of the offered products on the shelves of a supermarket or the pages of a mail-order catalog or web shop, may give hints which products may conveniently be bundled, or may allow to suggest other products to customers.

# %%
#seting the thresholds for minSupport and minConfidence
fpGrowth = FPGrowth(itemsCol="basket", minSupport=0.001, minConfidence=0)

model = fpGrowth.fit(shopping_baskets)

#calculating frequent item sets
frequent_items = model.freqItemsets
frequent_items.createOrReplaceTempView("frequentItems")

#display frequent itemsets
spark.sql('''select items, freq from frequentItems 
          where size(items) > 2 order by freq desc limit 20''').show(truncate =False)
# Out:
# +--------------------------------------------------------------------+----+
# |items                                                               |freq|
# +--------------------------------------------------------------------+----+
# |[Organic Hass Avocado, Organic Strawberries, Bag of Organic Bananas]|509 |
# |[Organic Raspberries, Organic Strawberries, Bag of Organic Bananas] |478 |
# |[Organic Baby Spinach, Organic Strawberries, Bag of Organic Bananas]|437 |
# |[Organic Raspberries, Organic Hass Avocado, Bag of Organic Bananas] |394 |
# |[Organic Hass Avocado, Organic Baby Spinach, Bag of Organic Bananas]|379 |
# |[Organic Avocado, Organic Baby Spinach, Banana]                     |367 |
# |[Organic Avocado, Large Lemon, Banana]                              |355 |
# |[Limes, Large Lemon, Banana]                                        |345 |
# |[Organic Cucumber, Organic Strawberries, Bag of Organic Bananas]    |317 |
# |[Organic Baby Spinach, Organic Strawberries, Banana]                |304 |
# |[Limes, Organic Avocado, Large Lemon]                               |299 |
# |[Organic Avocado, Organic Strawberries, Banana]                     |296 |
# |[Large Lemon, Organic Baby Spinach, Banana]                         |291 |
# |[Organic Raspberries, Organic Hass Avocado, Organic Strawberries]   |281 |
# |[Organic Blueberries, Organic Strawberries, Bag of Organic Bananas] |281 |
# |[Organic Cucumber, Organic Hass Avocado, Bag of Organic Bananas]    |272 |
# |[Limes, Organic Avocado, Banana]                                    |270 |
# |[Organic Lemon, Organic Hass Avocado, Bag of Organic Bananas]       |267 |
# |[Organic Avocado, Large Lemon, Organic Baby Spinach]                |263 |
# |[Large Lemon, Organic Strawberries, Banana]                         |261 |
# +--------------------------------------------------------------------+----+

# %% [markdown]
# # Association Rules sorted by Confidence

# %%
model.associationRules.orderBy("confidence", ascending=False).show(25, truncate=False)
# Out:
# +------------------------------------------------------------------+------------------------+-------------------+------------------+
# |antecedent                                                        |consequent              |confidence         |lift              |
# +------------------------------------------------------------------+------------------------+-------------------+------------------+
# |[Organic Raspberries, Organic Hass Avocado, Organic Strawberries] |[Bag of Organic Bananas]|0.5765124555160143 |4.900007315383391 |
# |[Organic Navel Orange, Organic Raspberries]                       |[Bag of Organic Bananas]|0.5707070707070707 |4.850665054413543 |
# |[Yellow Onions, Strawberries]                                     |[Banana]                |0.5408163265306123 |3.803571428571429 |
# |[Organic D'Anjou Pears, Organic Hass Avocado]                     |[Bag of Organic Bananas]|0.54               |4.589673518742443 |
# |[Organic Kiwi, Organic Hass Avocado]                              |[Bag of Organic Bananas]|0.5252918287937743 |4.464662955975139 |
# |[Organic Raspberries, Organic Hass Avocado]                       |[Bag of Organic Bananas]|0.5246338215712384 |4.4590702924114085|
# |[Organic Navel Orange, Organic Hass Avocado]                      |[Bag of Organic Bananas]|0.516245487364621  |4.387774523199421 |
# |[Organic Whole String Cheese, Organic Hass Avocado]               |[Bag of Organic Bananas]|0.5144230769230769 |4.3722851362663935|
# |[Organic Lemon, Organic Raspberries]                              |[Bag of Organic Bananas]|0.5107692307692308 |4.34122965305553  |
# |[Organic Large Extra Fancy Fuji Apple, Organic Hass Avocado]      |[Bag of Organic Bananas]|0.5013404825737265 |4.261090993967018 |
# |[Organic Navel Orange, Organic Strawberries]                      |[Bag of Organic Bananas]|0.5                |4.249697702539299 |
# |[Organic Unsweetened Almond Milk, Organic Hass Avocado]           |[Bag of Organic Bananas]|0.5                |4.249697702539299 |
# |[Organic Large Extra Fancy Fuji Apple, Organic Raspberries]       |[Bag of Organic Bananas]|0.49044585987261147|4.168493287841096 |
# |[Organic Hass Avocado, Organic Baby Spinach, Organic Strawberries]|[Bag of Organic Bananas]|0.4878048780487805 |4.146046539062731 |
# |[Honeycrisp Apple, Strawberries]                                  |[Banana]                |0.4831081081081081 |3.397708439571647 |
# |[Organic Fuji Apple, Strawberries]                                |[Banana]                |0.4823008849557522 |3.3920312239105024|
# |[Organic Kiwi, Organic Raspberries]                               |[Bag of Organic Bananas]|0.4765957446808511 |4.050775682420438 |
# |[Organic Yellow Squash]                                           |[Organic Zucchini]      |0.4755244755244755 |13.524410849266339|
# |[Organic Broccoli, Organic Hass Avocado]                          |[Bag of Organic Bananas]|0.47368421052631576|4.026029402405651 |
# |[Organic Kiwi, Organic Raspberries]                               |[Organic Strawberries]  |0.4723404255319149 |5.651888608328504 |
# |[Bunched Cilantro, Large Lemon]                                   |[Limes]                 |0.4723127035830619 |10.248821148576578|
# |[Organic Carrot Bunch, Organic Hass Avocado]                      |[Bag of Organic Bananas]|0.4721030042918455 |4.012590105401913 |
# |[Organic Lemon, Organic Cucumber]                                 |[Bag of Organic Bananas]|0.4676470588235294 |3.974717262963227 |
# |[Organic Large Extra Fancy Fuji Apple, Organic Baby Spinach]      |[Bag of Organic Bananas]|0.4604105571847507 |3.9132113741857473|
# |[Organic Gala Apples, Organic Hass Avocado]                       |[Bag of Organic Bananas]|0.4594594594594595 |3.905127618549626 |
# +------------------------------------------------------------------+------------------------+-------------------+------------------+
# only showing top 25 rows

# %% [markdown]
# # Recomendation Predictions

# %%
data = spark.sql("select p.product_name, o.order_id from products p inner join order_products_test o where o.product_id = p.product_id")
shopping_baskets_test = data.groupBy('order_id').agg(collect_list('product_name').alias('basket')).orderBy("order_id", ascending=True)
shopping_baskets_test.createOrReplaceTempView('shopping_baskets_test')
shopping_baskets_test.show()
# Out:
# +--------+--------------------+
# |order_id|              basket|
# +--------+--------------------+
# |       1|[Bulgarian Yogurt...|
# |      96|[Roasted Turkey, ...|
# |      98|[Natural Spring W...|
# |     112|[Fresh Cauliflowe...|
# |     218|[Natural Artisan ...|
# |     393|[Shredded Mexican...|
# |     473|[Organic Whole Mi...|
# |     631|[Organic Strawber...|
# |     774|[Ice Cream Variet...|
# |     904|[Cup Noodles Chic...|
# |    1280|[Lactose Free Hal...|
# |    1325|[Dha Omega 3 Redu...|
# |    1350|[Ground Cinnamon,...|
# |    1721|[Organic Reduced ...|
# |    1764|[Half & Half, Ita...|
# |    2011|[Limeade, Origina...|
# |    2021|[Granny Smith App...|
# |    2115|[Organic Mixed Ve...|
# |    2318|[Honey Vanilla Gr...|
# |    2530|[Total 2% Lowfat ...|
# +--------+--------------------+
# only showing top 20 rows

# %%
# transform examines the input items against all the association rules and summarize the
# consequents as prediction

predictions = model.transform(shopping_baskets_test).toPandas()

# %%
predictions.head(100)
# Out:
#     order_id                                             basket  \
# 0          1  [Bulgarian Yogurt, Organic 4% Milk Fat Whole M...
# 1         96  [Roasted Turkey, Organic Cucumber, Organic Gra...
# 2         98  [Natural Spring Water, Organic Orange Juice Wi...
# 3        112  [Fresh Cauliflower, I Heart Baby Kale, Sea Sal...
# 4        218  [Natural Artisan Water, Okra, Organic Yellow P...
# 5        393  [Shredded Mexican Blend Cheese, Clementines, F...
# 6        473  [Organic Whole Milk with DHA Omega-3, Banana, ...
# 7        631  [Organic Strawberries, Uncured Genoa Salami, O...
# 8        774  [Ice Cream Variety Pack, Nacho Cheese Sauce, D...
# 9        904    [Cup Noodles Chicken Flavor, Zero Calorie Cola]
# 10      1280  [Lactose Free Half & Half, Organic Half & Half...
# 11      1325  [Dha Omega 3 Reduced Fat 2% Milk, Bag of Organ...
# 12      1350  [Ground Cinnamon, Organic Insect Repellent Fre...
# 13      1721  [Organic Reduced Fat Milk, Organic Whole Milk,...
# 14      1764                  [Half & Half, Italian Dry Salame]
# 15      2011  [Limeade, Original Whole Fat Lactose Free Milk...
# 16      2021  [Granny Smith Apples, Organic Raw Unfiltered A...
# 17      2115  [Organic Mixed Vegetables, Organic Broccoli Fl...
# 18      2318  [Honey Vanilla Greek Yogurt, Flour Tortillas S...
# 19      2530  [Total 2% Lowfat Greek Strained Yogurt With Bl...
# 20      2603  [Bag of Organic Bananas, Uncured Hickory Smoke...
# 21      2822  [Bag of Organic Bananas, Tortillas, Corn, Orga...
# 22      2889  [Organic Unsweetened Almond Milk, 100% Pure Pu...
# 23      2937  [Banana, Florida Orange Juice With Calcium & V...
# 24      2948  [100% Whole Wheat Bread, Organic Mayonnaise, Y...
# 25      2985  [Sauvignon Blanc, English Seedless Cucumber, C...
# 26      3056  [GoGurt Yogurt Tubes Strawberry and Blue Raspb...
# 27      3091  [Lemon Ginger Tea Bags, Organic Mango Slices, ...
# 28      3179  [Lime Sparkling Water, Caramel Almond and Sea ...
# 29      3200  [Baby Cucumbers, Chocolate Chip Cookies, Straw...
# ..       ...                                                ...
# 70      5846  [Banana, Hearty Grains 100% Whole Wheat Englis...
# 71      5903  [Five Cheese & Garlic French Bread Pizza Singl...
# 72      5991                            [Orange Chicken, Pears]
# 73      6000  [Penne Rigate, Marinara Pasta Sauce, Organic S...
# 74      6096  [Organic Avocado, Red Beet Bunch, Organic Laci...
# 75      6315  [Banana, Roasted Turkey, Buttermilk Pancakes 8...
# 76      6394  [Bag of Organic Bananas, Organic Hass Avocado,...
# 77      6485  [Grilled Chicken Breast, Spicy Avocado Hummus,...
# 78      6552  [Sparkling Water Grapefruit, Gluten Free Fettu...
# 79      6601  [Spring Water, Sriracha Chicken Big Burrito, R...
# 80      6695  [Organic Kettle Corn, Dry Roasted Macadamias w...
# 81      6773  [Unrefined Virgin Coconut Oil, 100% Recycled P...
# 82      6845  [Heavy Whipping Cream, Sherry Reserve Vinegar,...
# 83      6935  [Holler Mountain Organic Coffee, Dill & Garlic...
# 84      6945                                       [Pinot Noir]
# 85      6971  [Lemon Yogurt, Raspberry Yoghurt, Peach Yoghur...
# 86      7019  [Chlorine Free Ultra-Thin Super Pads, Bonded F...
# 87      7044  [Extra Virgin Olive Oil, Organic Hass Avocado,...
# 88      7093  [Kellogg's Special K Strawberry Fruit Crisps 1...
# 89      7096                               [Beef Dinner Franks]
# 90      7318  [Organic Whole Wheat Bread, Flax Plus Organic ...
# 91      7559  [Raspberry Oikos Greek Yogurt, 2% Reduced Fat ...
# 92      7627  [Small Hass Avocado, Large Alfresco Eggs, Mapl...
# 93      7657  [Organic Romaine Lettuce, Organic Red Onion, B...
# 94      7741  [Grapefruit Sparkling Water, Orange Sparkling ...
# 95      7746  [100% White Grape Juice, Original Life Cereal,...
# 96      7865     [Taboule Salad, Organic Roasted Garlic Hummus]
# 97      8213  [Spicy Harissa Sauce, Globe Eggplant, Simply S...
# 98      8231  [Dill Pickle Spears, Granny Smith Apples, Gree...
# 99      8316  [Finely Shredded Mozzarella Cheese, 2% Reduced...
#
#                                            prediction
# 0   [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 1   [Limes, Organic Strawberries, Organic Avocado,...
# 2   [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 3   [Organic Cilantro, Asparagus, Limes, Organic W...
# 4   [Bag of Organic Bananas, Banana, Organic Straw...
# 5   [Raspberries, Bag of Organic Bananas, Organic ...
# 6   [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 7   [Banana, Asparagus, Limes, Organic Whole Milk,...
# 8                                                  []
# 9                                              [Soda]
# 10  [Limes, Organic Strawberries, Organic Avocado,...
# 11  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 12                                                 []
# 13  [Organic Strawberries, Bag of Organic Bananas,...
# 14  [Limes, Organic Whole Milk, Organic Strawberri...
# 15                                           [Banana]
# 16  [Limes, Banana, Organic Garlic, Asparagus, Org...
# 17  [Bag of Organic Bananas, Banana, Organic Straw...
# 18                                                 []
# 19  [Total 2% Greek Strained Yogurt with Cherry 5....
# 20  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 21  [Organic Tomato Basil Pasta Sauce, Organic Str...
# 22  [Jalapeno Peppers, Roma Tomato, Limes, Red Pep...
# 23  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 24  [Organic Strawberries, Organic Avocado, Strawb...
# 25  [Large Lemon, Banana, Organic Cilantro, Aspara...
# 26  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 27  [Organic Strawberries, Organic Yellow Onion, O...
# 28  [Sparkling Water Berry, Limes, Organic Strawbe...
# 29  [Hass Avocados, Raspberries, Bag of Organic Ba...
# ..                                                ...
# 70  [Organic Cilantro, Organic Large Extra Fancy F...
# 71  [Limes, Organic Strawberries, Organic Avocado,...
# 72                                                 []
# 73  [Limes, Banana, Organic Garlic, Organic Whole ...
# 74  [Organic Cilantro, Limes, Organic Grape Tomato...
# 75  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 76  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 77  [Organic Tomato Basil Pasta Sauce, Organic Sni...
# 78  [Green Bell Pepper, Asparagus, Limes, Red Pepp...
# 79  [Organic Strawberries, Bag of Organic Bananas,...
# 80  [Bag of Organic Bananas, Hass Avocados, Raspbe...
# 81  [Organic Strawberries, Bag of Organic Bananas,...
# 82  [Limes, Organic Yellow Onion, Organic Strawber...
# 83  [Organic Strawberries, Organic Avocado, Large ...
# 84                                                 []
# 85  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 86  [Organic Cilantro, Organic Large Extra Fancy F...
# 87  [Limes, Asparagus, Organic Strawberries, Organ...
# 88                                           [Banana]
# 89                                                 []
# 90  [Banana, Asparagus, Limes, Organic Whole Milk,...
# 91                                           [Banana]
# 92  [Limes, Organic Whole Milk, Organic Strawberri...
# 93  [Organic Tomato Basil Pasta Sauce, Marinara Sa...
# 94                    [Banana, Lemon Sparkling Water]
# 95  [Organic Strawberries, Organic Avocado, Large ...
# 96                                                 []
# 97  [Large Lemon, Organic Strawberries, Organic Zu...
# 98  [Banana, Large Lemon, Strawberries, Organic St...
# 99  [Banana, Limes, Asparagus, Organic Whole Milk,...
#
# [100 rows x 3 columns]

# %%
predictions.to_csv('predictions.csv')
